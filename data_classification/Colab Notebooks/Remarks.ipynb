# %% [markdown]
# # Remarks
#
# * NLP Process:
#   * https://zhuanlan.zhihu.com/p/36736328
#
# * Word embedding:
#   * Word2Vec:
#     * https://zhuanlan.zhihu.com/p/120148300
#   * BERT:
#     * https://zhuanlan.zhihu.com/p/46652512 (and a series of blogs by this author)
#
# * Machine Learning:
#   * SVM:
#     * Theory 1: https://zhuanlan.zhihu.com/p/77750026
#     * Theory 2: https://www.jiqizhixin.com/articles/2018-10-17-20
#
#
# * Image data augmentation:
#   * Main: https://zhuanlan.zhihu.com/p/41679153
#   * Definition of data augmentation factor(数据增强因子): https://blog.csdn.net/zhelong3205/article/details/81810743
#
# * Text data augmentation:
#   * https://www.zhihu.com/question/305256736
#   * EDA:
#       * https://zhuanlan.zhihu.com/p/85386829
#       * https://github.com/jasonwei20/eda_nlp
#       * https://arxiv.org/abs/1901.11196
#
# * BERT:
#   * BERT END TO END: https://colab.research.google.com/github/tensorflow/tpu/blob/master/tools/colab/bert_finetuning_with_cloud_tpus.ipynb
#   * https://zhuanlan.zhihu.com/p/46652512
#   * https://zhuanlan.zhihu.com/p/48612853
#   * https://www.jianshu.com/p/bfd0148b292e
#
#
# * Bi-directional LSTM:
#   * https://zhuanlan.zhihu.com/p/62486641
#   * https://github.com/u784799i/biLSTM_attn/blob/master/model.py
#   * https://github.com/cjbayron/sentiment-bi-rnn.pytorch/blob/master/sentiment_bi_rnn.py

# %% [markdown]
# # Remarks
#
# * Machine Learning General Introduction:
#   * https://blog.csdn.net/huanghaocs/article/details/88932072
#
# * Model Comparison:
#   * https://github.com/649453932/Chinese-Text-Classification-Pytorch
#
# * NLP Process:
#   * https://zhuanlan.zhihu.com/p/36736328
#
# * Word embedding:
#   * Word2Vec:
#     * https://zhuanlan.zhihu.com/p/120148300
#   * BERT:
#     * BERT END TO END: https://colab.research.google.com/github/tensorflow/tpu/blob/master/tools/colab/bert_finetuning_with_cloud_tpus.ipynb
#     * https://zhuanlan.zhihu.com/p/46652512 (and a series of blogs by this author)
#     * https://zhuanlan.zhihu.com/p/48612853
#     * https://www.jianshu.com/p/bfd0148b292e
#
# * Machine Learning:
#   * SVM:
#     * Theory 1: https://zhuanlan.zhihu.com/p/77750026
#     * Theory 2: https://www.jiqizhixin.com/articles/2018-10-17-20
#
# * Image data augmentation:
#   * Main: https://zhuanlan.zhihu.com/p/41679153
#   * Definition of data augmentation factor(数据增强因子): https://blog.csdn.net/zhelong3205/article/details/81810743
#
# * Text data augmentation:
#   * https://www.zhihu.com/question/305256736
#   * EDA:
#       * https://zhuanlan.zhihu.com/p/85386829
#       * https://github.com/jasonwei20/eda_nlp
#       * https://arxiv.org/abs/1901.11196

# %% [markdown]
# # Remarks
#
# * NLP Process:
#   * https://zhuanlan.zhihu.com/p/36736328
#
# * Word embedding:
#   * Word2Vec:
#     * https://zhuanlan.zhihu.com/p/120148300
#   * BERT:
#     * https://zhuanlan.zhihu.com/p/46652512 (and a series of blogs by this author)
#
# * Machine Learning:
#   * SVM:
#     * Theory 1: https://zhuanlan.zhihu.com/p/77750026
#     * Theory 2: https://www.jiqizhixin.com/articles/2018-10-17-20
#
#
# * Image data augmentation:
#   * Main: https://zhuanlan.zhihu.com/p/41679153
#   * Definition of data augmentation factor(数据增强因子): https://blog.csdn.net/zhelong3205/article/details/81810743
#
# * Text data augmentation:
#   * https://www.zhihu.com/question/305256736
#   * EDA:
#       * https://zhuanlan.zhihu.com/p/85386829
#       * https://github.com/jasonwei20/eda_nlp
#       * https://arxiv.org/abs/1901.11196
#
# * BERT:
#   * BERT END TO END: https://colab.research.google.com/github/tensorflow/tpu/blob/master/tools/colab/bert_finetuning_with_cloud_tpus.ipynb
#   * https://zhuanlan.zhihu.com/p/46652512
#   * https://zhuanlan.zhihu.com/p/48612853
#   * https://www.jianshu.com/p/bfd0148b292e
